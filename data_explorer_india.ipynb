# %%
import kagglehub
path1 = kagglehub.dataset_download("ruchikakumbhar/zomato-dataset")

print("Path to dataset files:", path1)
# Out:
# Path to dataset files: C:\Users\jains\.cache\kagglehub\datasets\ruchikakumbhar\zomato-dataset\versions\1

# %%
import kagglehub
path2 = kagglehub.dataset_download("sanjay3454chauhan/swiggy-dataset")

print("Path to dataset files:", path2)
# Out:
# ...
# 100%|██████████| 72.3k/72.3k [00:00<00:00, 244kB/s]
# Extracting files...
# Path to dataset files: C:\Users\jains\.cache\kagglehub\datasets\sanjay3454chauhan\swiggy-dataset\versions\1

# %%
import seaborn as sns
import  matplotlib.pyplot as plt
import pandas as pd

# %%
import os

print("ZOMATO files:")
print(os.listdir(path1))

print("\nSWIGGY files:")
print(os.listdir(path2))

import pandas as pd
import os

# Replace the filenames below with whatever Step 1 showed you
zomato = pd.read_csv(os.path.join(path1, 'Zomato-data-.csv'), encoding="latin-1")
swiggy = pd.read_csv(os.path.join(path2, 'swiggy_cleaned.csv'))

print("Zomato:", zomato.shape)
print("Swiggy:", swiggy.shape)
# Out:
# ZOMATO files:
# ['Zomato-data-.csv']
#
# SWIGGY files:
# ['swiggy_cleaned.csv', 'swiggy_scrap_uncleaned.csv']
# Zomato: (148, 7)
# Swiggy: (1749, 7)

# %%
swiggy
# Out:
#                                          hotel_name rating time_minutes  \
# 0                                        McDonald's   4.5            27
# 1                                               KFC   4.2            30
# 2                                    Domino's Pizza   4.3            25
# 3                  Charcoal Eats - Biryani & Beyond   4.3            24
# 4                                        Sandwizzaa   4.6            22
# ...                                             ...    ...          ...
# 1744                                       Allspice   3.8            48
# 1745                                 Poddar Cuisine   4.6            52
# 1746                                  JUG's Kitchen     4            48
# 1747  Choco Magic Patisserie & Confectioners Studio   4.1            43
# 1748                              Yogita Restaurant   3.9            58
#
#                                           food_type        location  \
# ...

# %%
zomato
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...
